# %% [markdown]
# # Tutorial 1: Getting started with Q-SPARC

# %% [markdown]
# In this series of tutorials, you will get a general idea of how to deploy and test the local LLM as the step1 to use `Q-SPARC`.
#
# This tutorial is an introduction to using a SCKAN knowledge database. The database being used as the example could be found in `tutorials\example`.
#
# Before running the examples, you must ensure you've installed these dependencies.
#
# `pip install -r requirements`

# %% [markdown]
# ## 1. Setting the environment

# %% [markdown]
# Create and activate a new Conda virtual environment with Python 3.11 to isolate project dependencies and avoid conflicts with other environments.
#
# `conda create -n llm_env python=3.11 -c conda-forge`
#
# `conda activate	 llm_env`

# %% [markdown]
# ## 2. Download LLM parameters from Hugging Face

# %% [markdown]
# Use the Hugging Face CLI tool to download the Qwen 3-32B large language model parameters with resume support, saving them to a specified local directory.
#
# **NOTE**: If your GPU memory is limited, you can change the smaller LLM `Qwen/Qwen3-0.6B` instead of `Qwen/Qwen3-32B`.
#
# `huggingface-cli download --resume-download Qwen/Qwen3-32B --local-dir /YOUR_PATH/Document/Code/LLMs/Qwen3-32B`

# %% [markdown]
# ## 3. Deploy it on the specific GPU

# %% [markdown]
# Launch the vLLM server, loading the downloaded model onto the specified GPU (GPU 0 here, you can choose any one available), exposing an HTTP API on port 8000(or another port recommand from 8000 to 9000) with optimized settings for efficient inference.
#
#
# `CUDA_VISIBLE_DEVICES=0 vllm serve /YOUR_PATH/Documents/Code/LLMs/Qwen3-32B --host 0.0.0.0 --port 8000 --dtype auto --max-num-seqs 32 --max-model-len 4096 --tensor-parallel-size 1 --trust-remote-code --gpu-memory-utilization 0.9`

# %% [markdown]
# ## 4. Check the LLM server status

# %% [markdown]
# Use the curl command to send a simple text generation request to the local LLM server to verify it is running properly and returning expected results.
#
# `curl --noproxy "*" http://localhost:8000/v1/completions \
# -H "Content-Type: application/json" \
# -d '{
# "model": "/YOUR_PATH/Documents/Code/LLMs/Qwen3-32B",
#  "prompt": "Where is the capital of New Zealand?",
# "max_tokens": 512
# }'`

# %% [markdown]
# The result should be as follows:
#
# `{"id":"cmpl-66060ef47d5f46fea01c97dff6ba35eb","object":"text_completion","created":1754357070,"model":"/hpc/fxu244/Documents/Code/LLMs/Qwen3-32B","choices":[{"index":0,"text":" The capital city of New Zealand is Wellington. It is located on the North Island of the country and serves as the seat of government for New Zealand. The city was chosen as the capital in 1865 due to its central location and deep-water harbor, which made it an ideal site for government and commerce. Wellington is also known for its vibrant cultural scene, beautiful natural surroundings, and as a hub for the film industry, particularly due to its association with the \"Lord of the Rings\" and \"The Hobbit\" film trilogies. Additionally, it is recognized for having one of the windiest capitals in the world. So, the answer is Wellington. $\\boxed{Wellington}$ ### Step 3","logprobs":null,"finish_reason":"length","stop_reason":null,"prompt_logprobs":null}],"service_tier":null,"system_fingerprint":null,"usage":{"prompt_tokens":8,"total_tokens":520,"completion_tokens":512,"prompt_tokens_details":null},"kv_transfer_params":null}`
